# %%
# To import csv files and read the headers
import pandas as pd

# %%
# Seprate delimiters by 

# %matplotlib inline
df_red = pd.read_csv('C:/Users/lebad/OneDrive/Desktop/Learing Projects/Udemy_Data_Analytics/Lesson4_Data_Analysis_Process/winequality-red.csv' , sep = ';')
df_white = pd.read_csv('C:/Users/lebad/OneDrive/Desktop/Learing Projects/Udemy_Data_Analytics/Lesson4_Data_Analysis_Process/winequality-white.csv' , sep = ';')

# %%
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# to check the volume of the data
df_white.shape
# Out:
# (4898, 12)

# %%
df_red.shape
# Out:
# (1599, 12)

# %%
df_red.size
# Out:
# 19188

# %%
df_red.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#duplicate rows in the white wine dataset
sum(df_white.duplicated())
# Out:
# 937

# %%
df_red.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
df_dup=df_red[df_red.duplicated()]
df_dup
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
# number of the unique value for an attribution
df_red['quality'].nunique()
# Out:
# 6

# %%
# number of the unique value for an attribution
df_white['quality'].nunique()
# Out:
# 7

# %%
# mean of an attribution
df_red['density'].mean()
# Out:
# 0.9967466791744833

# %%
M_Red = df_red['residual sugar'].mean()
M_Red
# Out:
# 2.5388055034396517

# %%
# Variance of an attribution
V_Red = df_red['residual sugar'].var()
V_Red
# Out:
# 1.9878971329859656

# %%
# combine two or more datasets
## first add a column or two for differentiating between data sets
import numpy as np
import pandas as pd
df_red = pd.read_csv('C:/Users/lebad/OneDrive/Desktop/Learing Projects/Udemy_Data_Analytics/Lesson4_Data_Analysis_Process/winequality-red.csv' , sep = ';')
df_white = pd.read_csv('C:/Users/lebad/OneDrive/Desktop/Learing Projects/Udemy_Data_Analytics/Lesson4_Data_Analysis_Process/winequality-white.csv' , sep = ';')

df_red = df_red.rename(index=str, columns={'total_sulfur-dioxide':'total_sulfur_dioxide'})

# %%
# create color array for red dataframe
color_red = np.repeat('Red', 1599, axis=0)

# create color array for white dataframe
color_white = np.repeat('White', 4898, axis=0)

# %%
df_red['color'] = color_red
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   Red
# 1      9.8        5   Red
# ...

# %%
df_white['color'] = color_white
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  White
# 1      9.5        6  White
# ...

# %%
# append dataframes
#DataFrame.append(dataframe, ignore_index=False, verify_integrity=False, sort=False)
#If True, the resulting axis will be labeled 0, 1, …, n - 1.
#If True, raise ValueError on creating index with duplicates.
#Sort columns if the columns of self and other are not aligned.
wine_df = df_red.append(df_white, ignore_index=True)

# view dataframe to check for success
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   Red
# 1      9.8        5   Red
# ...

# %%
# Save your newly combined dataframe as winequality_edited.csv. 
#Remember, set index=False to avoid saving with an unnamed column!
wine_df.to_csv('winequality_edited.csv',index=False)

# %%
import numpy as np
np.repeat(3, 4)
# Out:
# array([3, 3, 3, 3])

# %%
x = np.array([[1,2],[3,4]])
np.repeat(x, 2)
# Out:
# array([1, 1, 2, 2, 3, 3, 4, 4])

# %%
x = np.array([[1,2,3,4]])
np.repeat(x, 2)
# Out:
# array([1, 1, 2, 2, 3, 3, 4, 4])

# %%
np.repeat(x, 3, axis=1)
# Out:
# array([[1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4]])

# %%
x = np.array([[1,2],[3,4]])
np.repeat(x, 3, axis=1)
# Out:
# array([[1, 1, 1, 2, 2, 2],
#        [3, 3, 3, 4, 4, 4]])

# %%
x = np.array([[1,2],[3,4]])
np.repeat(x, 3, axis=0)
# Out:
# array([[1, 2],
#        [1, 2],
#        [1, 2],
#        [3, 4],
#        [3, 4],
#        [3, 4]])

# %%
np.repeat(x, [1, 2], axis=1)
# Out:
# array([[1, 2, 2],
#        [3, 4, 4]])

# %%
# Show histogram for data set 
import pandas as pd
winequality_df = pd.read_csv('winequality_edited.csv')
winequality_df['alcohol'].hist();

# %%
winequality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
winequality_df.plot(x='quality', y='pH', kind='scatter');

# %%
winequality_df.plot(x='quality', y='volatile acidity', kind='scatter');

# %%
pd.plotting.scatter_matrix(winequality_df,figsize=(25,25))
# Out:
# array([[<AxesSubplot:xlabel='fixed acidity', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='volatile acidity', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='citric acid', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='residual sugar', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='chlorides', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='free sulfur dioxide', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='total sulfur dioxide', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='density', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='pH', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='sulphates', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='alcohol', ylabel='fixed acidity'>,
#         <AxesSubplot:xlabel='quality', ylabel='fixed acidity'>],
#        [<AxesSubplot:xlabel='fixed acidity', ylabel='volatile acidity'>,
#         <AxesSubplot:xlabel='volatile acidity', ylabel='volatile acidity'>,
# ...

# %%
# Group by Function on the data set
import pandas as pd
winequality_df = pd.read_csv('winequality_edited.csv')
winequality_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   Red
# 1      9.8        5   Red
# ...

# %%
winequality_df.mean()
# Out:
# fixed acidity             7.215307
# volatile acidity          0.339666
# citric acid               0.318633
# residual sugar            5.443235
# chlorides                 0.056034
# free sulfur dioxide      30.525319
# total sulfur dioxide    115.744574
# density                   0.994697
# pH                        3.218501
# sulphates                 0.531268
# alcohol                  10.491801
# quality                   5.818378
# dtype: float64

# %%
winequality_df['sulphates'].mean()
# Out:
# 0.5312682776666163

# %%
winequality_df.groupby('sulphates').mean()
# Out:
#            fixed acidity  volatile acidity  citric acid  residual sugar  \
# sulphates
# 0.22            6.700000          0.210000     0.360000        8.550000
# 0.23            8.000000          0.340000     0.250000        6.400000
# 0.25            7.650000          0.398750     0.297500        4.512500
# 0.26            6.450000          0.317500     0.272500        6.450000
# 0.27            6.623077          0.306154     0.346154        6.434615
# ...                  ...               ...          ...             ...
# 1.61            8.900000          0.590000     0.500000        2.000000
# 1.62            7.100000          0.310000     0.300000        2.200000
# 1.95            8.600000          0.490000     0.280000        1.900000
# 1.98            8.600000          0.490000     0.290000        2.000000
# 2.00            9.200000          0.520000     1.000000        3.400000
#
#            chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# sulphates
# ...
