# %%
df = pd.read_csv('C:/Users/lebad/OneDrive/Desktop/Home/cancer_data.csv')
df.head()

# %%
# import Numpy
import pandas as pd
import mkl
import matplotlib
import numpy
import os
import pandas

# %%
# Just an exapmle of the data matrix
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['Name','Age'],dtype=float)
print (df)

# %%
# Read cvs files with other seprators
df = pd.read_csv('student_scores.csv', sep=':')
df.head()

# %%
# display first five rows of data
df.head()

# %%
# Anothe example of the data creation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandasql import sqldf
from pandasql import load_births

births=load_births()
print(sqldf("SELECT * FROM births WHERE births > 250000 limit 5", locals()))

# %%
# display attributes describtion
# print the column labels in the dataframe
for i, v in enumerate(df.columns):
    print(i, v)

# %%
# return the column labels
result = df.columns
  
# Print the result
print(result)

# %%
# this returns a tuple of the dimensions of the dataframe
df.shape

# %%
# this returns the datatypes of the columns
df.dtypes

# %%
# although the datatype for diagnosis appears to be object, further
# investigation shows it's a string
type(df['diagnosis'][0])

# %%
# this displays a concise summary of the dataframe,
# including the number of non-null values in each column
df.info()

# %%
# this returns the number of unique values in each column
df.nunique()

# %%
# this returns useful descriptive statistics for each column of data#####
df.describe()

# %%
# this returns the first few lines in our dataframe
# by default, it returns the first five
df.head()

# %%
# although, you can specify however many rows you'd like returned
df.head(20)

# %%
p=df.head(20)
print(p)

# %%
# same thing applies to `.tail()` which returns the last few rows
df.tail(2)

# %%
# select all the columns from 'id' to the last mean column
df_means = df.loc[:,'id':'fractal_dimension_mean']
df_means.head(20)

#prevent your first line of data from being misinterpreted as column labels
df = pd.read_csv('student_scores.csv', header=None)
df.head()

#specify your own column labels 
labels = ['id', 'name', 'attendance', 'hw', 'test1', 'project1', 'test2', 'project2', 'final']
df = pd.read_csv('student_scores.csv', names=labels)
df.head()

#tell pandas that there was a header line that you are replacing, you can specify the row of that line
labels = ['id', 'name', 'attendance', 'hw', 'test1', 'project1', 'test2', 'project2', 'final']
df = pd.read_csv('student_scores.csv', header=0, names=labels)
df.head()

#you can specify one or more of your columns to be the index of your dataframe
df = pd.read_csv('student_scores.csv', index_col='Name')
# df = pd.read_csv('student_scores.csv', index_col=['Name', 'ID'])
df.head()

# %%
# load caner data into data frame
df = pd.read_csv('C:/Users/lebad/OneDrive/Desktop/Home/cancer_data.csv')

# %%
df_means.to_csv('C:/Users/lebad/OneDrive/Desktop/Home/cancer_data_means.csv', index=False)

# %%
# import
import numpy as np

# create the standard errors dataframe
df_standards=df.iloc[:,np.r_[0:1, 12:21]]

# view the first few rows to confirm this was successful
df_standards.head()

# %%
df_standards.to_csv('C:/Users/lebad/OneDrive/Desktop/Home/cancer_data_standard.csv')

# %%
# fill the missing data with mean
mean=df['view_Duration'].mean()
df['view_Duration']= df['view_Duration'].fillna(mean)
# or
df['view_Duration'].fillna(mean,inplace=True)

# %%
# find the duplicates
df.duplicated()
# find the number of duplicates
sum(df.duplicated())
# drop the duplicates lines
df.drop_duplicates(inplace=True)


# incorrect data types
df.info()
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df = pd.read_csv('C:/Users/lebad/OneDrive/Desktop/Home/cancer_data.csv')
df.info()

# %%
df.duplicated()

# %%
sum(df.duplicated())

# %%
# remove "_mean" from column names from cancer dt set
new_labels = []
for col in df.columns:
    if '_mean' in col:
        new_labels.append(col[:-5])  # exclude last 6 characters
    else:
        new_labels.append(col)

# new labels for our columns
new_labels

# %%
# assign new labels to columns in dataframe
df.columns = new_labels

# display first few rows of dataframe to confirm changes
df.head()

# %%
#### Visualization
import pandas as pd
% matplotlib inline


df = pd.read_csv('C:/Users/lebad/OneDrive/Desktop/Home/cancer_data.csv')
# Out:
# UsageError: Line magic function `%` not found.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius                   569 non-null    float64
#  3   texture                  569 non-null    float64
#  4   perimeter                569 non-null    float64
#  5   area                     569 non-null    float64
#  6   smoothness               569 non-null    float64
#  7   compactness              569 non-null    float64
#  8   concavity                569 non-null    float64
#  9   concave points           569 non-null    float64
#  10  symmetry                 569 non-null    float64
#  11  fractal_dimension        569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# plot histograms
df.hist(figsize=(20,20));

# %%
# histogram for one variable
df['concavity_worst'].hist();
# or in more general way
df['area_worst'].plot(kind='hist',color='blue',figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Bar & Pie charts
df['diagnosis'].value_counts()
#df['diagnosis'].value_counts().plot(kind='bar',color='red',figsize=(7,7));
df['diagnosis'].value_counts().plot(kind='pie',figsize=(7,7));

# %%
df.plot(x='smoothness',y='compactness',kind='scatter');

# %%
#smoothness               569 non-null    float64
# 7   compactness              569 non-null    float64
 #8   concavity                569 non-null    float64
# 9   concave points           569 non-null    float64
 #10  symmetry

# %%
df.plot(x='concave points',y='symmetry',kind='box');

# %%
# total sales for the last month,row 196 to the last row which is first row
df.iloc[196:, 1:].sum()

# %%
# sales on march 13, 2016
df[df['week'] == '2016-03-13']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'week'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-80d59e4291a2> in <module>
#       1 # sales on march 13, 2016
# ...

# %%
# worst week for store C
df[df['storeC'] == df['storeC'].min()]
